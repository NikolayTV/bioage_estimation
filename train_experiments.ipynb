# %% [markdown]
# ## Топовые предикторы

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from catboost import CatBoostRegressor
import numpy as np
from sklearn.metrics import r2_score
from tqdm.auto import tqdm
from src.core import predict_and_average, fill_na_from_lookup, remove_young_data, upscale_with_nans

pd.set_option('display.max_rows', 50)

# %%
df = pd.read_csv('train_data.csv', index_col=0)

print(df.shape)
# Remove rows with age below 5 and above 85
df = df[(df['age']>15) & (df['age']<85)]

age_bins = np.arange(15, 90, 5)
age_labels = [f'{age_bins[i]}-{age_bins[i+1]-1}' for i in range(len(age_bins)-1)]
# Create a new column for age groups
df['Age Group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

print(df.shape)

# Формируем отложенную выборку
df = df.sample(frac=1, random_state=42)
test_df = df[int(df.shape[0]*0.8):]
df = df[:int(df.shape[0]*0.8)]
print('test_df.shape, df.shape', test_df.shape, df.shape)

df[:5]
# Out:
# (121745, 16)
# (78051, 17)
# test_df.shape, df.shape (15611, 17) (62440, 17)
#         Systolic blood pressure average  \
# 118445                              NaN
# 80656                               NaN
# 81934                               NaN
# 81243                               NaN
# 109034                              NaN
#
#         Estimated Glomerular Filtration Rate (mL/min/1.73 m2)  \
# 118445                                         117.006838
# 80656                                           59.731341
# 81934                                          116.620323
# 81243                                          107.327123
# 109034                                          64.844737
#
#         alpha-tocopherol (µg/dL)  Serum homocysteine: SI (umol/L)  \
# 118445                     825.0                              NaN
# 80656                        NaN                              NaN
# 81934                        NaN                              NaN
# 81243                        NaN                              NaN
# 109034                       NaN                              NaN
#
#         Serum ferritin (ng/mL)  Serum creatinine (mg/dL)  \
# 118445                    88.8                      0.82
# 80656                      NaN                      1.27
# 81934                     16.0                      0.74
# 81243                      NaN                      1.01
# 109034                     NaN                      1.14
#
#         Serum blood urea nitrogen (mg/dL)  Serum HDL cholesterol (mg/dL)  \
# 118445                               13.0                           49.0
# 80656                                10.0                           34.0
# 81934                                 9.0                           37.0
# 81243                                 9.0                           25.0
# 109034                               13.0                           37.0
#
#         Serum albumin:  SI (g/L)  Serum C-reactive protein (mg/dL)  \
# 118445                      39.0                               NaN
# 80656                       38.0                              0.40
# 81934                       42.0                              0.54
# 81243                       42.0                              0.39
# 109034                      45.0                               NaN
#
#         Body Mass Index (kg/m**2)  Waist to Height ratio  gender  age  \
# 118445                      30.58               0.652976    Male   32
# 80656                       22.40               0.499438    Male   63
# 81934                       29.87               0.607854  Female   20
# 81243                       38.88               0.741163    Male   19
# 109034                      22.15               0.424293    Male   17
#
#         Respondent sequence number  \
# 118445                     99297.0
# 80656                      56583.0
# 81934                      57965.0
# 81243                      57220.0
# 109034                     88998.0
#
#        Respondent sequence number that includes an identifier for NHANES III and NHANES continuous  \
# 118445                                            C-99297
# 80656                                             C-56583
# 81934                                             C-57965
# 81243                                             C-57220
# 109034                                            C-88998
#
#        Age Group
# 118445     30-34
# 80656      60-64
# 81934      20-24
# 81243      15-19
# 109034     15-19

# %%
features = [
# 'Waist Circumference (cm)', эти фичи не участвуют в создании модели
#  'Standing Height (cm)',
#  'Weight (kg)',
 'Systolic blood pressure average',
 'Estimated Glomerular Filtration Rate (mL/min/1.73 m2)',
 'alpha-tocopherol (µg/dL)',
 'Serum homocysteine: SI (umol/L)',
 'Serum ferritin (ng/mL)',
 'Serum creatinine (mg/dL)',
 'Serum blood urea nitrogen (mg/dL)',
 'Serum HDL cholesterol (mg/dL)',
 'Serum albumin:  SI (g/L)',
 'Serum C-reactive protein (mg/dL)',
 'Body Mass Index (kg/m**2)',
 'Waist to Height ratio']

meta_features = ['gender', 'age', 'Respondent sequence number', 'Respondent sequence number that includes an identifier for NHANES III and NHANES continuous']

# %%
print(df[features].describe())
print(df[features].isnull().sum())
# Out:
#        Systolic blood pressure average  \
# count                      8700.000000
# mean                        122.833678
# std                          20.014779
# min                          72.000000
# 25%                         109.000000
# 50%                         119.000000
# 75%                         132.000000
# max                         266.000000
#
#        Estimated Glomerular Filtration Rate (mL/min/1.73 m2)  \
# count                                       58216.000000
# mean                                           89.814329
# std                                            24.691208
# min                                             1.854450
# 25%                                            72.931985
# 50%                                            90.005900
# 75%                                           107.470172
# max                                           300.155982
#
#        alpha-tocopherol (µg/dL)  Serum homocysteine: SI (umol/L)  \
# count              21373.000000                     22610.000000
# mean                1217.114584                         8.728067
# std                  578.695980                         4.682432
# min                    7.000000                         1.610000
# 25%                  851.000000                         6.310000
# 50%                 1080.000000                         7.900000
# 75%                 1410.000000                         9.970000
# max                13083.900000                       145.000000
#
#        Serum ferritin (ng/mL)  Serum creatinine (mg/dL)  \
# count            33519.000000              58243.000000
# mean               112.586310                  0.922603
# std                147.829983                  0.430558
# min                  1.040000                  0.100000
# 25%                 30.000000                  0.720000
# 50%                 68.000000                  0.900000
# 75%                142.000000                  1.040000
# max               5190.000000                 17.800000
#
#        Serum blood urea nitrogen (mg/dL)  Serum HDL cholesterol (mg/dL)  \
# count                       58240.000000                   58416.000000
# mean                           13.448592                      52.399385
# std                             5.811192                      15.650774
# min                             1.000000                       6.000000
# 25%                            10.000000                      41.000000
# 50%                            13.000000                      50.000000
# 75%                            16.000000                      61.000000
# max                           122.000000                     226.000000
#
#        Serum albumin:  SI (g/L)  Serum C-reactive protein (mg/dL)  \
# count              58246.000000                      40484.000000
# mean                  42.294647                          0.445696
# std                    3.797085                          0.834133
# min                    9.000000                          0.010000
# 25%                   40.000000                          0.120000
# 50%                   42.000000                          0.210000
# 75%                   45.000000                          0.450000
# max                   61.000000                         29.600000
#
#        Body Mass Index (kg/m**2)  Waist to Height ratio
# count               61495.000000           58850.000000
# mean                   28.100436               0.573913
# std                     6.702141               0.099250
# min                    11.990000               0.333870
# 25%                    23.410000               0.500891
# 50%                    27.010000               0.566722
# 75%                    31.460000               0.635865
# max                   130.210000               1.137113
# Systolic blood pressure average                          53740
# Estimated Glomerular Filtration Rate (mL/min/1.73 m2)     4224
# alpha-tocopherol (µg/dL)                                 41067
# Serum homocysteine: SI (umol/L)                          39830
# Serum ferritin (ng/mL)                                   28921
# Serum creatinine (mg/dL)                                  4197
# Serum blood urea nitrogen (mg/dL)                         4200
# Serum HDL cholesterol (mg/dL)                             4024
# Serum albumin:  SI (g/L)                                  4194
# Serum C-reactive protein (mg/dL)                         21956
# Body Mass Index (kg/m**2)                                  945
# Waist to Height ratio                                     3590
# dtype: int64

# %% [markdown]
# # Undersampling

# %%
df_reduced = remove_young_data(df, age_column='age', age_threshold=20, removal_fraction=0.4)
# Now `df_reduced` will have 20% fewer rows for individuals below 20 years of age.
df_reduced.shape
# Out:
# (59306, 17)

# %%
df_reduced.groupby('age').count()['Systolic blood pressure average'].plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
# Distribution of the target variable
plt.figure(figsize=(8, 6))
sns.histplot(df_reduced['age'], bins=df_reduced['age'].nunique(), kde=True, )
plt.title('Age Distribution')
plt.show()

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df_reduced[features].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# # Upscaling

# %%
# Example usage:
# This example doubles the dataset size with augmented data having at least 40% missing values in each feature
df_upscaled = upscale_with_nans(df_reduced, features, missing_fraction=0.4, upscale_factor=1)
sns.histplot(df_upscaled['age'], bins=df_reduced['age'].nunique(), kde=True, )
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df_reduced[features].isna().sum() / df_reduced.shape[0]
# Out:
# Systolic blood pressure average                          0.865494
# Estimated Glomerular Filtration Rate (mL/min/1.73 m2)    0.066233
# alpha-tocopherol (µg/dL)                                 0.665346
# Serum homocysteine: SI (umol/L)                          0.639632
# Serum ferritin (ng/mL)                                   0.467305
# Serum creatinine (mg/dL)                                 0.065946
# Serum blood urea nitrogen (mg/dL)                        0.065997
# Serum HDL cholesterol (mg/dL)                            0.063231
# Serum albumin:  SI (g/L)                                 0.065896
# Serum C-reactive protein (mg/dL)                         0.353455
# Body Mass Index (kg/m**2)                                0.015192
# Waist to Height ratio                                    0.058527
# dtype: float64

# %%
df_upscaled[features].isna().sum() / df_upscaled.shape[0]
# Out:
# Systolic blood pressure average                          0.892456
# Estimated Glomerular Filtration Rate (mL/min/1.73 m2)    0.252571
# alpha-tocopherol (µg/dL)                                 0.732202
# Serum homocysteine: SI (umol/L)                          0.711825
# Serum ferritin (ng/mL)                                   0.573559
# Serum creatinine (mg/dL)                                 0.252420
# Serum blood urea nitrogen (mg/dL)                        0.252605
# Serum HDL cholesterol (mg/dL)                            0.250725
# Serum albumin:  SI (g/L)                                 0.252909
# Serum C-reactive protein (mg/dL)                         0.483551
# Body Mass Index (kg/m**2)                                0.212103
# Waist to Height ratio                                    0.246366
# dtype: float64

# %%
def fill_na_with_age_group_mean(df, features=None, age_bins=None):
    """
    Fills NaN values in specified columns with the mean of their respective age group.

    Parameters:
    - df: pandas.DataFrame, the original dataset.
    - features: list of str, the names of the columns for which NaN values should be filled with the group mean.
    - age_bins: list of int, the bin edges for grouping ages. If None, default age groups are used.

    Returns:
    - df_filled: pandas.DataFrame, the dataset after filling NaN values with age group means.
    """
    # Create a copy of the DataFrame to avoid modifying the original data
    df_filled = df.copy()
    
    # Fill NaN for each specified target column
    for col in features:
        if col in df_filled.columns:
            # Calculate and fill NaNs with the mean of their age group
            df_filled[col] = df_filled.groupby('Age Group')[col].transform(lambda x: x.fillna(x.mean()))
    
    return df_filled

# Example usage:
df_filled = fill_na_with_age_group_mean(df_upscaled, 
            features=features)

df_filled[features].isna().sum() / df_filled.shape[0]
# Out:
# /var/folders/fh/jpzybjhs0nq0265pm39s6kf80000gn/T/ipykernel_60098/644187997.py:20: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_filled[col] = df_filled.groupby('Age Group')[col].transform(lambda x: x.fillna(x.mean()))
# Systolic blood pressure average                          0.0
# Estimated Glomerular Filtration Rate (mL/min/1.73 m2)    0.0
# alpha-tocopherol (µg/dL)                                 0.0
# Serum homocysteine: SI (umol/L)                          0.0
# Serum ferritin (ng/mL)                                   0.0
# Serum creatinine (mg/dL)                                 0.0
# Serum blood urea nitrogen (mg/dL)                        0.0
# Serum HDL cholesterol (mg/dL)                            0.0
# Serum albumin:  SI (g/L)                                 0.0
# Serum C-reactive protein (mg/dL)                         0.0
# Body Mass Index (kg/m**2)                                0.0
# Waist to Height ratio                                    0.0
# dtype: float64

# %%
avgs_for_age_group = df_filled.groupby(['Age Group'])[features].mean()
avgs_for_age_group.to_csv('avgs_for_age_group.csv')
# avgs_for_age_group = pd.read_csv('avgs_for_age_group.csv')
avgs_for_age_group
# Out:
# /var/folders/fh/jpzybjhs0nq0265pm39s6kf80000gn/T/ipykernel_60098/1271632596.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avgs_for_age_group = df_filled.groupby(['Age Group'])[features].mean()
#            Systolic blood pressure average  \
# Age Group
# 15-19                           112.228850
# 20-24                           112.599095
# 25-29                           113.342857
# 30-34                           113.504931
# 35-39                           115.680681
# 40-44                           120.061657
# 45-49                           123.981522
# 50-54                           125.377880
# 55-59                           130.652961
# 60-64                           134.955975
# 65-69                           138.768278
# 70-74                           140.797619
# 75-79                           143.987109
# 80-84                           147.516315
#
#            Estimated Glomerular Filtration Rate (mL/min/1.73 m2)  \
# Age Group
# 15-19                                             102.826335
# 20-24                                             110.888641
# 25-29                                             106.485162
# 30-34                                             102.226190
# 35-39                                              97.968387
# 40-44                                              93.686809
# 45-49                                              90.900338
# 50-54                                              86.701738
# 55-59                                              82.380945
# 60-64                                              78.032352
# 65-69                                              71.729300
# 70-74                                              67.670267
# 75-79                                              62.113290
# 80-84                                              58.026389
#
#            alpha-tocopherol (µg/dL)  Serum homocysteine: SI (umol/L)  \
# Age Group
# 15-19                    816.628506                         7.039205
# 20-24                    952.941691                         7.457802
# 25-29                   1087.740457                         7.462720
# 30-34                   1125.382841                         7.504886
# 35-39                   1167.722176                         7.982979
# 40-44                   1237.687490                         8.438454
# 45-49                   1301.694081                         8.867625
# 50-54                   1370.214228                         9.251201
# 55-59                   1436.011683                         9.462701
# 60-64                   1469.159354                         9.868399
# 65-69                   1493.082401                        10.354512
# 70-74                   1526.654521                        11.085963
# 75-79                   1549.025858                        11.839631
# 80-84                   1596.365053                        12.037720
#
#            Serum ferritin (ng/mL)  Serum creatinine (mg/dL)  \
# Age Group
# 15-19                   48.425474                  0.817943
# 20-24                   66.626549                  0.855694
# 25-29                   82.597811                  0.863677
# 30-34                   91.430373                  0.862988
# 35-39                  103.717588                  0.877525
# 40-44                  106.351090                  0.892651
# 45-49                  123.761555                  0.894276
# 50-54                  164.933124                  0.913307
# 55-59                  174.764365                  0.940882
# 60-64                  188.047409                  0.973846
# 65-69                  175.970867                  1.040985
# 70-74                  167.426334                  1.038558
# 75-79                  161.820415                  1.092258
# 80-84                  160.531758                  1.142216
#
#            Serum blood urea nitrogen (mg/dL)  Serum HDL cholesterol (mg/dL)  \
# Age Group
# 15-19                              10.842666                      51.155691
# 20-24                              11.162294                      52.148345
# 25-29                              11.414378                      53.054430
# 30-34                              11.537723                      51.630284
# 35-39                              11.992395                      51.295334
# 40-44                              12.345266                      51.164691
# 45-49                              12.713817                      51.926991
# 50-54                              13.589229                      52.795238
# 55-59                              14.195111                      53.680270
# 60-64                              15.205024                      52.745350
# 65-69                              16.159068                      53.045161
# 70-74                              16.774981                      53.259418
# 75-79                              18.059443                      54.040098
# 80-84                              20.125529                      54.845510
#
#            Serum albumin:  SI (g/L)  Serum C-reactive protein (mg/dL)  \
# Age Group
# 15-19                     44.231242                          0.245116
# 20-24                     42.975170                          0.388365
# 25-29                     42.667515                          0.399842
# 30-34                     42.372993                          0.444459
# 35-39                     42.425049                          0.410289
# 40-44                     42.178201                          0.420533
# 45-49                     42.054098                          0.457283
# 50-54                     42.133428                          0.477320
# 55-59                     41.889607                          0.516767
# 60-64                     41.611126                          0.577221
# 65-69                     41.611956                          0.566931
# 70-74                     41.315423                          0.539327
# 75-79                     41.196049                          0.558292
# 80-84                     40.746689                          0.575908
#
#            Body Mass Index (kg/m**2)  Waist to Height ratio
# Age Group
# 15-19                      25.021131               0.502620
# 20-24                      26.489514               0.530281
# 25-29                      27.506748               0.550048
# 30-34                      28.475508               0.565596
# 35-39                      28.816303               0.572579
# 40-44                      29.250354               0.583014
# 45-49                      29.447190               0.590012
# 50-54                      29.497376               0.598224
# 55-59                      29.521643               0.605252
# 60-64                      29.532223               0.613251
# 65-69                      29.196274               0.614342
# 70-74                      28.624018               0.615070
# 75-79                      27.982382               0.610594
# 80-84                      26.666031               0.600981

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from joblib import dump, load
import sys, os

def train_and_save_models(model, df, features, save_to='models/', n_splits=5):
    if not os.path.exists(save_to): os.mkdir(save_to)
    models_saved = []
    X = df[features]
    y = df["age"]

    kf = KFold(n_splits=n_splits)
    fold = 0
    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        df.loc[df.iloc[test_index].index, 'y_pred'] = y_pred.tolist()

        # Save the model for this fold
        model_filename = f'{save_to}/model_fold_{fold}.joblib'
        dump(model, model_filename)
        models_saved.append(model_filename)
        print(f'Model saved for fold {fold}: {model_filename}')

    return df, models_saved

# %%
train_df = df_upscaled.copy()
train_df = train_df.dropna()
train_df.dropna()['age'].hist(bins=train_df['age'].nunique())
# Out:
# <Axes: >

# %%
train_df, models_saved = train_and_save_models(
    CatBoostRegressor(silent=True, random_state=42, max_depth=5), 
    train_df, features, save_to='models/catboost')
mae = mean_absolute_error(train_df['age'], train_df['y_pred'])
r2 = r2_score(train_df['age'], train_df['y_pred'])

print('MAE', mae, 'R2', r2)
# Plot y_pred against age
plt.figure(figsize=(10, 6))
plt.scatter(train_df['age'], train_df['y_pred'], alpha=0.5)
plt.title('Predicted Age vs. Actual Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.plot([train_df['age'].min(), train_df['age'].max()], [train_df['age'].min(), train_df['age'].max()], 'k--') # Diagonal line
plt.show()
# Out:
# Model saved for fold 1: models/catboost/model_fold_1.joblib
# Model saved for fold 2: models/catboost/model_fold_2.joblib
# Model saved for fold 3: models/catboost/model_fold_3.joblib
# Model saved for fold 4: models/catboost/model_fold_4.joblib
# Model saved for fold 5: models/catboost/model_fold_5.joblib
# MAE 4.906359761973523 R2 0.8712426051276689

# %%
# Plot 1, 2: Actual age vs predicted age for each gender (using Seaborn)
sns.regplot(
    x=train_df['age'],
    y=train_df['y_pred'],
    marker='o',
    scatter_kws={'s': 5, 'alpha': 0.9},
    order=4, 
    x_estimator=np.mean
)
# Out:
# <Axes: xlabel='age', ylabel='y_pred'>

# %%
cb_model = load(models_saved[3])
cb_model.get_feature_importance(prettified=True)
# Out:
#                                            Feature Id  Importances
# 0   Estimated Glomerular Filtration Rate (mL/min/1...    37.274690
# 1                               Waist to Height ratio    15.428224
# 2                            Serum creatinine (mg/dL)    14.515654
# 3                   Serum blood urea nitrogen (mg/dL)     7.465487
# 4                              Serum ferritin (ng/mL)     7.095173
# 5                           Body Mass Index (kg/m**2)     5.716171
# 6                            alpha-tocopherol (µg/dL)     3.906427
# 7                            Serum albumin:  SI (g/L)     2.627706
# 8                     Serum homocysteine: SI (umol/L)     2.095987
# 9                     Systolic blood pressure average     1.820607
# 10                      Serum HDL cholesterol (mg/dL)     1.167198
# 11                   Serum C-reactive protein (mg/dL)     0.886675

# %% [markdown]
# ## get baseline scores

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Assuming y is already defined from the earlier steps

# Calculate the mean of the target variable
y_mean = df['age'].mean()

# Create an array of mean values that has the same shape as y for baseline prediction
y_pred_baseline = [y_mean] * len(df['age'])

# Calculate MAE and R^2 for the baseline
mae_baseline = mean_absolute_error(df['age'], y_pred_baseline)
r2_baseline = r2_score(df['age'], y_pred_baseline)

mae_baseline, r2_baseline
# Out:
# (17.2437881737384, 0.0)

# %% [markdown]
# # Inference

# %%
cb_model.feature_names_
# Out:
# ['Systolic blood pressure average',
#  'Estimated Glomerular Filtration Rate (mL/min/1.73 m2)',
#  'alpha-tocopherol (µg/dL)',
#  'Serum homocysteine: SI (umol/L)',
#  'Serum ferritin (ng/mL)',
#  'Serum creatinine (mg/dL)',
#  'Serum blood urea nitrogen (mg/dL)',
#  'Serum HDL cholesterol (mg/dL)',
#  'Serum albumin:  SI (g/L)',
#  'Serum C-reactive protein (mg/dL)',
#  'Body Mass Index (kg/m**2)',
#  'Waist to Height ratio']

# %%
models_paths = ['models/catboost/model_fold_1.joblib',
 'models/catboost/model_fold_2.joblib',
 'models/catboost/model_fold_3.joblib',
 'models/catboost/model_fold_4.joblib',
 'models/catboost/model_fold_5.joblib']
final_predictions = predict_and_average(test_df.iloc[0], models_saved)
final_predictions
# Out:
# 23.447280395812776

# %% [markdown]
# # Проверяем точность на отложенной выборке

# %%
predictions = []

for i in tqdm(range(test_df.shape[0])):
    # Extract a single row as a DataFrame
    row = test_df.iloc[[i]]
    # Get the prediction for the current row
    final_pred = predict_and_average(row, models_saved)
    # Append the prediction to the list
    predictions.extend(final_pred)

# Add the predictions as a new column to the DataFrame
test_df['final_pred'] = predictions

mae_final_pred = mean_absolute_error(test_df['age'], test_df['final_pred'])
r2_final_pred = r2_score(test_df['age'], test_df['final_pred'])
mae_final_pred, r2_final_pred
# Out:
#   0%|          | 0/15611 [00:00<?, ?it/s]
# (6.713979801338043, 0.7642829564018541)

# %%
age_bins = np.arange(15, 90, 5)
age_labels = [f'{age_bins[i]}-{age_bins[i+1]-1}' for i in range(len(age_bins)-1)]

# Assuming the task is regression. For classification, you might use accuracy_score instead
age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))

age_group_mae.plot(kind='bar')
plt.title('Model Performance by Age Group')
plt.xlabel('Age Group')
plt.ylabel('MAE')  # Or replace with 'Accuracy' or other relevant metrics
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2652563027.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2652563027.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2652563027.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2652563027.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))

# %% [markdown]
# ## Проверяем точность на отложенной выборке с заполненными пропусками средними значениями для возрастной группы

# %%
test_df_filled = fill_na_from_lookup(test_df, features, avgs_for_age_group)
test_df_filled
# Out:
#         Waist Circumference (cm)  Standing Height (cm)  Weight (kg)  \
# 95356                      109.3                170.70       103.60
# 13293                      113.8                160.10        92.60
# 50976                       77.6                170.80        67.50
# 90700                       90.7                161.50        63.10
# 121162                     116.6                157.30        95.60
# ...                          ...                   ...          ...
# 6471                        79.0                175.00        70.55
# 87213                      102.3                169.70        92.50
# 119971                      81.0                178.70        71.70
# 890                         96.8                167.65        90.60
# 16304                      107.2                181.00        95.20
#
#         Systolic blood pressure average  \
# 95356                        112.495050
# 13293                        113.861493
# 50976                        115.679474
# 90700                        144.091727
# 121162                       130.597720
# ...                                 ...
# 6471                         113.861493
# 87213                        111.363748
# 119971                       112.495050
# 890                          112.495050
# 16304                        113.257773
#
#         Estimated Glomerular Filtration Rate (mL/min/1.73 m2)  \
# 95356                                          119.206718
# 13293                                           84.011053
# 50976                                           92.869973
# 90700                                           76.195561
# 121162                                          94.272299
# ...                                                   ...
# 6471                                            88.354872
# 87213                                          108.714062
# 119971                                         101.908596
# 890                                             92.044151
# 16304                                           96.807756
#
#         alpha-tocopherol (µg/dL)  Serum homocysteine: SI (umol/L)  \
# 95356                 955.642725                         7.400403
# 13293                1128.114758                         7.900000
# 50976                1535.000000                         7.990000
# 90700                1547.801201                        11.828074
# 121162               1330.000000                         9.396372
# ...                          ...                              ...
# 6471                 1128.114758                         7.486355
# 87213                 808.931160                         7.136765
# 119971               1140.000000                         7.400403
# 890                   955.642725                         7.400403
# 16304                1091.098963                         8.950000
#
#         Serum ferritin (ng/mL)  Serum creatinine (mg/dL)  \
# 95356                66.741876                      0.91
# 13293                 8.000000                      0.90
# 50976                78.000000                      0.80
# 90700               162.912085                      0.76
# 121162              120.000000                      0.72
# ...                        ...                       ...
# 6471                 87.000000                      1.10
# 87213                49.908892                      0.64
# 119971              102.000000                      1.03
# 890                  45.000000                      0.90
# 16304               378.000000                      1.05
#
#         Serum blood urea nitrogen (mg/dL)  Serum HDL cholesterol (mg/dL)  \
# 95356                                13.0                           47.0
# 13293                                13.0                           37.0
# 50976                                 7.0                           75.0
# 90700                                 8.0                           78.0
# 121162                               14.0                           58.0
# ...                                   ...                            ...
# 6471                                 16.0                           51.0
# 87213                                 6.0                           62.0
# 119971                               13.0                           48.0
# 890                                  10.0                           38.0
# 16304                                16.5                           30.0
#
#         Serum albumin:  SI (g/L)  Serum C-reactive protein (mg/dL)  \
# 95356                       48.0                          0.390157
# 13293                       38.0                          0.400000
# 50976                       46.0                          0.170000
# 90700                       47.0                          0.567360
# 121162                      37.0                          0.516858
# ...                          ...                               ...
# 6471                        42.0                          0.210000
# 87213                       39.0                          0.247499
# 119971                      46.0                          0.390157
# 890                         41.0                          0.210000
# 16304                       42.5                          0.210000
#
#         Body Mass Index (kg/m**2)  Waist to Height ratio  gender  age  \
# 95356                       35.55               0.640305       1   22
# 13293                       36.13               0.710806       2   33
# 50976                       23.14               0.454333       2   39
# 90700                       24.19               0.561610       2   76
# 121162                      38.64               0.741259       2   55
# ...                           ...                    ...     ...  ...
# 6471                        23.04               0.451429       1   32
# 87213                       32.12               0.602829       2   16
# 119971                      22.45               0.453274       1   23
# 890                         32.23               0.577393       2   20
# 16304                       29.06               0.592265       1   27
#
#             SEQN  SEQN_new Age Group
# 95356    74169.0   C-74169     20-24
# 13293    42138.0   I-42138     30-34
# 50976    24204.0   C-24204     35-39
# 90700    67454.0   C-67454     75-79
# 121162  102309.0  C-102309     55-59
# ...          ...       ...       ...
# 6471     16039.0   I-16039     30-34
# 87213    63656.0   C-63656     15-19
# 119971  100985.0  C-100985     20-24
# 890       2107.0    I-2107     20-24
# 16304    49238.0   I-49238     25-29
#
# [15611 rows x 20 columns]

# %%
predictions = []

for i in tqdm(range(test_df_filled.shape[0])):
    # Extract a single row as a DataFrame
    row = test_df_filled.iloc[[i]]
    # Get the prediction for the current row
    final_pred = predict_and_average(row, models_saved)
    # Append the prediction to the list
    predictions.extend(final_pred)

# Add the predictions as a new column to the DataFrame
test_df_filled['final_pred'] = predictions

mae_final_pred = mean_absolute_error(test_df_filled['age'], test_df_filled['final_pred'])
r2_final_pred = r2_score(test_df_filled['age'], test_df_filled['final_pred'])
mae_final_pred, r2_final_pred
# Out:
#   0%|          | 0/15611 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 12
#       9     predictions.extend(final_pred)
#      11 # Add the predictions as a new column to the DataFrame
# ---> 12 test_df_filled['final_pred'] = predictions
#      14 mae_final_pred = mean_absolute_error(test_df_filled['age'], test_df_filled['final_pred'])
#      15 r2_final_pred = r2_score(test_df_filled['age'], test_df_filled['final_pred'])
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4296     self._setitem_array([key], value)
#    4297 else:
#    4298     # set column
# -> 4299     self._set_item(key, value)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4512, in DataFrame._set_item(self, key, value)
#    4502 def _set_item(self, key, value) -> None:
#    4503     """
#    4504     Add series to DataFrame in specified column.
#    4505
#    (...)
#    4510     ensure homogeneity.
#    4511     """
# -> 4512     value, refs = self._sanitize_column(value)
#    4514     if (
#    4515         key in self.columns
#    4516         and value.ndim == 1
#    4517         and not isinstance(value.dtype, ExtensionDtype)
#    4518     ):
#    4519         # broadcast across multiple columns if necessary
#    4520         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5253, in DataFrame._sanitize_column(self, value)
#    5250     return _reindex_for_setitem(value, self.index)
#    5252 if is_list_like(value):
# -> 5253     com.require_length_match(value, self.index)
#    5254 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5255 if (
#    5256     isinstance(value, Index)
#    5257     and value.dtype == "object"
#    (...)
#    5260     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5261     # this deprecation
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (31222) does not match length of index (15611)

# %%
age_bins = np.arange(15, 90, 5)
age_labels = [f'{age_bins[i]}-{age_bins[i+1]-1}' for i in range(len(age_bins)-1)]

# Assuming the task is regression. For classification, you might use accuracy_score instead
age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))

age_group_mae.plot(kind='bar')
plt.title('Model Performance by Age Group')
plt.xlabel('Age Group')
plt.ylabel('MAE')  # Or replace with 'Accuracy' or other relevant metrics
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2670566794.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2670566794.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_group_mae = test_df.groupby('Age Group').apply(lambda x: mean_absolute_error(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2670566794.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))
# /var/folders/gm/xnklr9cn25d9zttg6821cbrw0000gp/T/ipykernel_84664/2670566794.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_group_r2 = test_df.groupby('Age Group').apply(lambda x: r2_score(x['age'], x['final_pred']))

# %% [markdown]
# Точность с заполненными пропусками сильно выше чем если их не заполнять
# * Проверили на отложенной выборки. Заполненные средние были взять из трейна, проверили на тесте

# %%
age_bins = np.arange(15, 90, 5)
age_labels = [f'{age_bins[i]}-{age_bins[i+1]-1}' for i in range(len(age_bins)-1)]
age_group = pd.cut([15], bins=age_bins, labels=age_labels, right=False)[0]
age_group
# Out:
# '15-19'

# %%
avgs_for_age_group = pd.read_csv('avgs_for_age_group.csv')
avgs_for_age_group
# Out:
#    Age Group  Systolic blood pressure average  \
# 0      15-19                       112.314975
# 1      20-24                       112.584821
# 2      25-29                       113.038855
# 3      30-34                       113.742661
# 4      35-39                       115.506599
# 5      40-44                       120.223070
# 6      45-49                       124.264171
# 7      50-54                       126.075829
# 8      55-59                       129.978441
# 9      60-64                       134.949474
# 10     65-69                       138.447242
# 11     70-74                       140.221180
# 12     75-79                       144.719852
# 13     80-84                       147.506641
#
#     Estimated Glomerular Filtration Rate (mL/min/1.73 m2)  \
# 0                                          102.974162
# 1                                          110.876844
# 2                                          106.462157
# 3                                          102.527722
# 4                                           97.945347
# 5                                           93.616479
# 6                                           90.990562
# 7                                           86.693294
# 8                                           82.226339
# 9                                           78.006829
# 10                                          71.822312
# 11                                          67.384233
# 12                                          62.255868
# 13                                          58.026701
#
#     alpha-tocopherol (µg/dL)  Serum homocysteine: SI (umol/L)  \
# 0                 813.673358                         7.057153
# 1                 953.960897                         7.444368
# 2                1091.054808                         7.433134
# 3                1126.764388                         7.405990
# 4                1168.355411                         7.968919
# 5                1229.775282                         8.365948
# 6                1297.543909                         8.779729
# 7                1371.554680                         9.405109
# 8                1439.090814                         9.424954
# 9                1466.345462                         9.870632
# 10               1502.452292                        10.439757
# 11               1523.643384                        11.040474
# 12               1559.359321                        11.777582
# 13               1589.904506                        12.118570
#
#     Serum ferritin (ng/mL)  Serum creatinine (mg/dL)  \
# 0                48.606190                  0.814755
# 1                66.905666                  0.856325
# 2                83.662469                  0.860469
# 3                91.309555                  0.861975
# 4               104.241582                  0.875635
# 5               106.334720                  0.890900
# 6               123.806325                  0.892437
# 7               163.951370                  0.906321
# 8               174.857238                  0.947325
# 9               185.884286                  0.971510
# 10              177.113943                  1.043289
# 11              168.219038                  1.037882
# 12              164.463963                  1.087298
# 13              162.031626                  1.139954
#
#     Serum blood urea nitrogen (mg/dL)  Serum HDL cholesterol (mg/dL)  \
# 0                           10.863530                      51.083249
# 1                           11.149702                      52.061157
# 2                           11.430205                      52.942553
# 3                           11.548718                      51.656108
# 4                           11.981995                      51.350539
# 5                           12.358655                      51.146032
# 6                           12.679515                      51.871848
# 7                           13.632387                      52.809227
# 8                           14.203011                      53.795772
# 9                           15.180112                      52.740102
# 10                          16.177749                      52.857143
# 11                          16.778498                      53.353661
# 12                          17.992509                      53.962591
# 13                          20.161802                      54.742303
#
#     Serum albumin:  SI (g/L)  Serum C-reactive protein (mg/dL)  \
# 0                  44.187218                          0.256098
# 1                  42.989710                          0.390366
# 2                  42.647329                          0.406392
# 3                  42.365454                          0.437173
# 4                  42.449018                          0.396973
# 5                  42.189936                          0.416758
# 6                  42.078499                          0.450600
# 7                  42.119558                          0.462013
# 8                  41.893048                          0.511389
# 9                  41.628636                          0.568233
# 10                 41.589045                          0.565080
# 11                 41.338031                          0.542221
# 12                 41.216976                          0.563404
# 13                 40.693623                          0.574719
#
#     Body Mass Index (kg/m**2)  Waist to Height ratio
# 0                   24.953700               0.501618
# 1                   26.502920               0.530784
# 2                   27.502835               0.549562
# 3                   28.457388               0.565031
# 4                   28.904226               0.573036
# 5                   29.307041               0.583670
# 6                   29.439802               0.589781
# 7                   29.419433               0.597468
# 8                   29.476234               0.604913
# 9                   29.553518               0.612975
# 10                  29.186834               0.615391
# 11                  28.681900               0.614209
# 12                  27.996941               0.610705
# 13                  26.626365               0.599867

# %%
print('\n asd')
# Out:
#  asd
